# %% [markdown]
# ### Name: Meron Abebe
# ### Student ID: GSR/4256/18

# %% [markdown]
# ### Part 1: Basic Input & Output ###

# %%
name= "Abel"
age= "20"
print("hello"  ,  name,"!"  , "you are" ,  age ,  "years old")
# Out:
# hello Abel ! you are 20 years old

# %% [markdown]
#  ### Part 2: Even or Odd Checker ###

# %%
no= 8
if no % 2 ==0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %% [markdown]
# ### Part 3: Loop Practice

# %%
for i in range(1,21):
  if i % 3 ==0 and i % 5 ==0:
       print("FrizzBuzz")
  elif i % 3 ==0:
      print("Frizz")
  elif i % 5 ==0:
      print("Buzz")
  else:
      print(i)
# Out:
# 1
# 2
# Frizz
# 4
# Buzz
# Frizz
# 7
# 8
# Frizz
# Buzz
# 11
# Frizz
# 13
# 14
# FrizzBuzz
# 16
# 17
# Frizz
# 19
# Buzz

# %% [markdown]
# ### Part 4: List Operations ###

# %%
numbers = [12, 11, 3, 23, 64]
print("Largest number:", max(numbers))
print("Smallest number:", min(numbers))
print("Sum of all numbers:", sum(numbers))
# Out:
# Largest number: 64
# Smallest number: 3
# Sum of all numbers: 113

# %% [markdown]
# ### Part 5: Dictionary Task

# %%
student = {
    "name": "Abel",
    "age": 20,
    "grade": "A"
}

student["city"] = "Addis Ababa"
student["grade"] = "A+"
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Abel
# age : 20
# grade : A+
# city : Addis Ababa

# %% [markdown]
# ### Part 6: Function

# %%
def calculate_area(length, width):
    return length * width
area = calculate_area(11, 8)
print("The area of the rectangle is:", area)
# Out:
# The area of the rectangle is: 88

# %% [markdown]
# ### Part 7: Mini Project

# %%
num1 = float(input("Enter first number: 11 "))
num2 = float(input("Enter second number: 12"))
operation = input("Enter operation (+, -, *, /): ")
if operation == "+":
    result = num1 + num2
elif operatioThen == "-":
    result = num1 - num2
elif operation == "*":
    result = num1 * num2
elif operation == "/":
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
else:
    result = "Invalid operation!"

# %%
# for some reason i couldn't run this particular code
